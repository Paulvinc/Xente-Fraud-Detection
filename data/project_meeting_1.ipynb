# %% [markdown]
# # Project meeting 1

# %% [markdown]
# # latihan membuat varibale

# %%
# variable pertama, dengan string, tulis nama anda


#kemudian print

# %%
# variable kedua, dengan boolean, True False masing-masing ditulis 5x dengan menggunakan Tuple(), seperti contoh fam = 5, 5, 5, 5, 5 pada module


#kemudian print

# %%
# variable ketiga, dengan integer, angka 1 - 10



#kemudian print

# %%
# varible keempat, dengan floating hasil dari 1 + 0.5, 2 + 0.7, 3 + 0.6


#kemudian print

# %% [markdown]
# # Latihan Membuat Working Directory

# %%
# buat folder di PC masing-masing dengan format seperti ini

# > dtsense_code
        # >> codes
        # >> data
            # >>> input
            # >>> output
        # >> figures

# %%
# set up working directory

import os

# set up working directory di PC masing-masing

os.chdir("C:\\Users\\Maria Ulfah\\Downloads\\dtsense_codes") # hanya contoh

# %%
# cek lokasi working directory

os.getcwd()
# Out:
# 'C:\\Users\\Maria Ulfah\\Downloads\\dtsense_codes'

# %% [markdown]
# # Kalkulasi dengan operator aritmatika
# # Python as Calculator

# %%
# Kalikan 10 dengan 15, buat variable x, lalu print

# %%
# jumlahkan "Saya" dengan "Cantik", buat variable y, lalu print

# %%
# jumlahkan True dengan False, buat variable z, lalu print

# %%
# cari modulo 5 dari 69, buat variable m, lalu print

# %%
# berapa hasil kuadrat dari 28989, buat variable q, lalu print

# %% [markdown]
# # Calculating & Converting Variable Values

# %%
grade = 100 - 3.5
student = "Syahrini"
fakta = True

# buatlah text dibawah ini dengan informasi dari kombinasi variable di atas
# "Berita tentang Syahrini mendapatkan nilai ujian 96.5 adalah True"

infotainment =


# kemudian print

# %% [markdown]
# # Menggunakan Basic Functions di Python

# %%
dream_job = "saya ingin menjadi data scientist"

# ganti huruf pertama dari text di varible dream_job menjadi huruf kapital
# gunakan .capitalize() function
# Out:
# 'Saya ingin menjadi data scientist'

# %%
# Rubah semua huruf dari text yang ada pada dream_job menjadi huruf kapital
# gunakan .upper() function

# %%
student_grade = 86.5, 98, 67, 86, 55.6, 65, 75, 80.7, 65, 70

# Cari nilai tertinggi yang ada pada student_grade
# Out:
# 74.88000000000001

# %%
# sortir nilai student dari yang paling tinggi ke yang paling rendah

# %%
# sortir nilai student dari yang paling rendah ke yang paling tinggi

# %%
# hitung panjang element yang ada pada student_grade

# %%
# Hitung nilai rata-rata dari student_grade
